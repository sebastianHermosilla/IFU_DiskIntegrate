# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import FunctionsDiskIntegrate as di
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits

di.visualize("Data\FEIGE-110_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_NIR.fits")

# %%
data, wave, center = di.Atmospheric_dispersion_correction("Data\FEIGE-110_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_NIR.fits")

# %%
clean_data, wave = di.Sigma_clipping_adapted_for_IFU("", data=data, wave=wave)

# %%
fig, axes = plt.subplots(1, 1, figsize=(18, 10))
axes.plot(wave, data[:, center[0], center[1]], linewidth=0.5)
axes.plot(wave, clean_data[:, center[0], center[1]], linewidth=0.5)
axes.set_ylim(0, 2000)
# Out:
# (0.0, 2000.0)

# %%
di.optimal_radius_selection_IFU("", center, 1500, 1700, data=clean_data, wave=wave, spaxelsFit=9, error=3, plots=True)
# Out:
# [1499.97998869 1500.03998869 1500.09998869 ... 1699.83998422 1699.89998422
#  1699.95998422]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# [438.44209159 452.06654053 453.60857538 ... 401.32750599 407.34795229
#  413.5551168 ]
# ...

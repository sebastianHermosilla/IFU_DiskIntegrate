# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\FEIGE-110_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_UVB.fits", 
                                   lower_limit=450, 
                                   upper_limit=480, 
                                   correct_center_x=True, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=None, 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=25, 
                                   error=3)
# Out:
# c:\Users\shermosilla\Desktop\trabajos\Graduado_proyects\IFU_DiskIntegrate\FunctionsDiskIntegrate.py:408: RuntimeWarning: invalid value encountered in sqrt
#   return alpha*np.sqrt(x + cte)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\FEIGE-110_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_VIS.fits", 
                                   lower_limit=580, 
                                   upper_limit=620, 
                                   correct_center_x=False, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=(600, 950), 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=100, 
                                   percentage=20, 
                                   error=3)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\FEIGE-110_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_NIR.fits", 
                                   lower_limit=2100, 
                                   upper_limit=2150, 
                                   correct_center_x=False, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=None, 
                                   plots=True, 
                                   max_plots=3.5, 
                                   A_sc=3, 
                                   window_sc=100, 
                                   percentage=20, 
                                   error=3)

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\GD71_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_UVB.fits", 
                                   lower_limit=450, 
                                   upper_limit=480, 
                                   correct_center_x=False, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=(350, 550), 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=25, 
                                   error=3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_122600\3322112033.py in <module>
#       1 import FunctionsDiskIntegrate as di
# ----> 2 data, wave = di.process_my_ifu_obs("Data\GD71_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_UVB.fits",
#       3                                    lower_limit=450,
#       4                                    upper_limit=480,
#       5                                    correct_center_x=True,
#
# c:\Users\shermosilla\Desktop\trabajos\Graduado_proyects\IFU_DiskIntegrate\FunctionsDiskIntegrate.py in process_my_ifu_obs(fits_path, lower_limit, upper_limit, correct_center_x, correct_center_y, look_center_x, look_center_y, plots, max_plots, A_sc, window_sc, percentage, error)
#     506     data, wave, pix_x, pix_y, dx, dy = visualize(fits_path)
#     507
# ...

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\GD71_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_VIS.fits", 
                                   lower_limit=580, 
                                   upper_limit=620, 
                                   correct_center_x=False, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=(600, 950), 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=20, 
                                   error=3)

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\GD71_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_NIR.fits", 
                                   lower_limit=2100, 
                                   upper_limit=2150, 
                                   correct_center_x=False, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=None, 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=25, 
                                   error=3.5)

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\LTT7987_Saturn_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_UVB.fits", 
                                   lower_limit=450, 
                                   upper_limit=480, 
                                   correct_center_x=True, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=None, 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=25, 
                                   error=3)

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\LTT7987_Saturn_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_VIS.fits", 
                                   lower_limit=580, 
                                   upper_limit=620, 
                                   correct_center_x=False, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=(600, 950), 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=20, 
                                   error=3)

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\LTT7987_Saturn_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_NIR.fits", 
                                   lower_limit=2100, 
                                   upper_limit=2150, 
                                   correct_center_x=False, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=None, 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=25, 
                                   error=3.5)

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\LTT7987_Titan_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_UVB.fits", 
                                   lower_limit=450, 
                                   upper_limit=480, 
                                   correct_center_x=True, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=None, 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=25, 
                                   error=3)

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\LTT7987_Titan_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_VIS.fits", 
                                   lower_limit=580, 
                                   upper_limit=620, 
                                   correct_center_x=False, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=(600, 950), 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=20, 
                                   error=3)

# %%
import FunctionsDiskIntegrate as di
data, wave = di.process_my_ifu_obs("Data\LTT7987_Titan_onoff_IFU_FLUX_IFU_MERGE3D_DATA_OBJ_NIR.fits", 
                                   lower_limit=2100, 
                                   upper_limit=2150, 
                                   correct_center_x=False, 
                                   correct_center_y=True, 
                                   look_center_x=None, 
                                   look_center_y=None, 
                                   plots=True, 
                                   max_plots=3, 
                                   A_sc=3, 
                                   window_sc=20, 
                                   percentage=25, 
                                   error=3.5)
